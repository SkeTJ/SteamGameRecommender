# %% [markdown]
# <a href="https://colab.research.google.com/github/SkeTJ/SteamGameRecommender/blob/main/SteamGameRecommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import numpy as np
from pandas import json_normalize
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
import difflib

# Load the Drive helper and mount
from google.colab import drive
import os.path
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
api_key = ''
steam_key = {'key': api_key, 'max_results': 50000}
def get_app_list():
  # Get initial batch of list
  store_app_list_url = 'https://api.steampowered.com/IStoreService/GetAppList/v1/'
  app_list = requests.get(url = store_app_list_url, params = steam_key).json()

  df = pd.DataFrame(app_list)
  df = json_normalize(df['response']['apps'])

  # Get Last App ID to complete the DataFrame
  last_appid = df['appid'].iloc[-1]
  df_list = [df]
  while True:
    appid_params = {'key': api_key, 'last_appid': last_appid,'max_results': 50000}
    new_df = requests.get(url = store_app_list_url, params = appid_params).json()
    new_df = pd.DataFrame(new_df)
    if new_df.empty:
      break

    new_df = json_normalize(new_df['response']['apps'])

    # Append the new data to a DataFrame
    df_list.append(new_df)

    # Iterate to the next last App ID
    last_appid = new_df['appid'].iloc[-1]

  df = pd.concat(df_list)

  # Remove Unnecessary Columns
  df = df.drop(['last_modified', 'price_change_number'], axis = 1)
  df = df.dropna()

  return df

# %%
appid_df = get_app_list()

# %%
appid_df
# Out:
#          appid                       name
# 0           10             Counter-Strike
# 1           20      Team Fortress Classic
# 2           30              Day of Defeat
# 3           40         Deathmatch Classic
# 4           50  Half-Life: Opposing Force
# ...        ...                        ...
# 40889  2615670         Bewitching Sinners
# 40890  2616050         Dual Bus Simulator
# 40891  2616060      Blackhole on the Road
# 40892  2616080  BUBG Single on the Ground
# 40893  2617030                  Pond Scum
#
# [90894 rows x 2 columns]

# %%
# LOWER THE DATASET FOR NOW, TO BE REMOVED
halved_df = appid_df[:-90500]

# %%
halved_df.head(5)
# Out:
#    appid                       name
# 0     10             Counter-Strike
# 1     20      Team Fortress Classic
# 2     30              Day of Defeat
# 3     40         Deathmatch Classic
# 4     50  Half-Life: Opposing Force

# %%
halved_df.tail(5)
# Out:
#      appid                                           name
# 389  15930                                        Luxor 3
# 390  15960                                    Little Farm
# 391  15970                                          Luxor
# 392  16000           Discovery! A Seek and Find Adventure
# 393  16020  Samantha Swift and the Hidden Roses of Athena

# %% [markdown]
# # Get the specific details of each app based on the App ID

# %%
# Requests will be made in two since the app details is in one API
# requests whilst the review is also in a different API request.
def get_app_details(appid_df):
  # Prepare CSV file
  csv_file_name = "steam_app_list.csv"
  csv_file_location = f''
  remove_header = False

  # Check whether CSV file exists
  if os.path.exists(csv_file_location):
    steam_app_df = pd.read_csv(csv_file_location)
    last_appid = steam_app_df['steam_appid'].iloc[-1]

    # Since the CSV exist, we do not need to apply the header again
    remove_header = True

    # Get the last index of the CSV
    temp_df = appid_df.loc[appid_df['appid'] == last_appid]
    last_index = temp_df.index[0]

    # Get the last App ID index and remove irrelevant rows
    appid_df = appid_df[last_index + 1:]
    appids = appid_df.appid
  else:
    appids = appid_df.appid

  game_list = []
  for appid in appids:
    app_detail_url = f'http://store.steampowered.com/api/appdetails?appids={appid}'
    app_review_url = f'https://store.steampowered.com/appreviews/{appid}?json=1&language=all&purchase_type=all&num_per_page=0'

    app_detail = requests.get(url = app_detail_url).json()
    app_review = requests.get(url = app_review_url).json()['query_summary']
    try:
      app_df = pd.DataFrame(app_detail)
      app_df = json_normalize(app_df[f'{appid}'])
      review_df = pd.json_normalize(app_review)

      # Clean Review DataFrame before attaching to main App DataFrame
      review_df = review_df.drop(['num_reviews'], axis = 1)

      # WORKAROUND
      # The DataFrame always return a 2nd row (1 in the index) with all NaN values
      # So I figured that it should just be removed everytime the it is made into a DataFrame
      app_df = app_df.drop(1)

      # Append both App and Review DataFrame together
      app_df = pd.concat([app_df, review_df], axis = 1)

      game_list.append(app_df)
    except:
      continue

  df = pd.concat(game_list)
  df = df.reset_index()
  df = df.drop(['index'], axis = 1)

  # Append to the CSV
  if remove_header == True:
    # Resume from the last index
    df.index = np.arange(last_index, last_index  + (len(df)))
    df.to_csv(csv_file_location, mode = 'a', header = None)
  else:
    df.to_csv(csv_file_location, mode = 'a')

  return df

# %%
apps_df = get_app_details(halved_df)

# %%
apps_df
# Out:
#      type                                           name  steam_appid  \
# 0    game                                 Counter-Strike         10.0
# 1    game                          Team Fortress Classic         20.0
# 2    game                                  Day of Defeat         30.0
# 3    game                             Deathmatch Classic         40.0
# 4    game                      Half-Life: Opposing Force         50.0
# ..    ...                                            ...          ...
# 363  game                                        Luxor 3      15930.0
# 364  game                                    Little Farm      15960.0
# 365  game                                          Luxor      15970.0
# 366  game           Discovery! A Seek and Find Adventure      16000.0
# 367  game  Samantha Swift and the Hidden Roses of Athena      16020.0
#
#     required_age is_free                               detailed_description  \
# 0            0.0   False  Play the world's number 1 online action game. ...
# 1            0.0   False  One of the most popular online action games of...
# 2            0.0   False  Enlist in an intense brand of Axis vs. Allied ...
# 3            0.0   False  Enjoy fast-paced multiplayer gaming with Death...
# 4            0.0   False  Return to the Black Mesa Research Facility as ...
# ..           ...     ...                                                ...
# 363          0.0   False  A brave young Pharaoh, killed prematurely by a...
# 364          0.0   False  Have a down-home good time at Little Farm, whe...
# 365          0.0   False  Addictive and exciting, Luxor is an action-puz...
# 366          0.0   False  Break out your magnifying glass and passport-I...
# 367          0.0   False  On a quest to recover the Scepter of Zeus for ...
#
#                                         about_the_game  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 363  A brave young Pharaoh, killed prematurely by a...
# 364  Have a down-home good time at Little Farm, whe...
# 365  Addictive and exciting, Luxor is an action-puz...
# 366  Break out your magnifying glass and passport-I...
# 367  On a quest to recover the Scepter of Zeus for ...
#
#                                      short_description  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 363  A brave young Pharaoh, killed prematurely by a...
# 364  Have a down-home good time at Little Farm, whe...
# 365  Addictive and exciting, Luxor is an action-puz...
# 366  Break out your magnifying glass and passport-I...
# 367  On a quest to recover the Scepter of Zeus for ...
#
#                                    supported_languages  \
# 0    English<strong>*</strong>, French<strong>*</st...
# 1    English, French, German, Italian, Spanish - Sp...
# 2    English, French, German, Italian, Spanish - Spain
# 3    English, French, German, Italian, Spanish - Sp...
# 4                      English, French, German, Korean
# ..                                                 ...
# 363                                            English
# 364                                            English
# 365                   English, French, German, Swedish
# 366                                            English
# 367                                            English
#
#                                           header_image  ...  \
# 0    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 1    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 2    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 3    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 4    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# ..                                                 ...  ...
# 363  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 364  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 365  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 366  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 367  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
#
#     achievements.highlighted pc_requirements.recommended controller_support  \
# 0                        NaN                         NaN                NaN
# 1                        NaN                         NaN                NaN
# 2                        NaN                         NaN                NaN
# 3                        NaN                         NaN                NaN
# 4                        NaN                         NaN                NaN
# ..                       ...                         ...                ...
# 363                      NaN                         NaN                NaN
# 364                      NaN                         NaN                NaN
# 365                      NaN                         NaN                NaN
# 366                      NaN                         NaN                NaN
# 367                      NaN                         NaN                NaN
#
#     reviews linux_requirements.recommended legal_notice pc_requirements  \
# 0       NaN                            NaN          NaN             NaN
# 1       NaN                            NaN          NaN             NaN
# 2       NaN                            NaN          NaN             NaN
# 3       NaN                            NaN          NaN             NaN
# 4       NaN                            NaN          NaN             NaN
# ..      ...                            ...          ...             ...
# 363     NaN                            NaN          NaN             NaN
# 364     NaN                            NaN          NaN             NaN
# 365     NaN                            NaN          NaN             NaN
# 366     NaN                            NaN          NaN             NaN
# 367     NaN                            NaN          NaN             NaN
#
#     drm_notice mac_requirements.recommended ext_user_account_notice
# 0          NaN                          NaN                     NaN
# 1          NaN                          NaN                     NaN
# 2          NaN                          NaN                     NaN
# 3          NaN                          NaN                     NaN
# 4          NaN                          NaN                     NaN
# ..         ...                          ...                     ...
# 363        NaN                          NaN                     NaN
# 364        NaN                          NaN                     NaN
# 365        NaN                          NaN                     NaN
# 366        NaN                          NaN                     NaN
# 367        NaN                          NaN                     NaN
#
# [368 rows x 64 columns]

# %%
apps_df['recommendations.total'][0]
# Out:
# 139169.0

# %%
apps_df['detailed_description'].head(5)
# Out:
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# Name: detailed_description, dtype: object

# %%
apps_df['developers'].head(5)
# Out:
# 0               [Valve]
# 1               [Valve]
# 2               [Valve]
# 3               [Valve]
# 4    [Gearbox Software]
# Name: developers, dtype: object

# %%
apps_df['categories'].head(5)
# Out:
# 0    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4    [{'id': 2, 'description': 'Single-player'}, {'...
# Name: categories, dtype: object

# %%
apps_df['genres'].head(5)
# Out:
# 0    [{'id': '1', 'description': 'Action'}]
# 1    [{'id': '1', 'description': 'Action'}]
# 2    [{'id': '1', 'description': 'Action'}]
# 3    [{'id': '1', 'description': 'Action'}]
# 4    [{'id': '1', 'description': 'Action'}]
# Name: genres, dtype: object

# %%
# Unpack categories
def get_list(x):
  if isinstance(x, list):
    descriptions = [i['description'] for i in x]
    if len(descriptions) > 5:
      descriptions = descriptions[:5]
    return descriptions

  # If there are no description provided, just return nothing
  return []

# %%
features = ['categories', 'genres']
for feature in features:
  apps_df[feature] = apps_df[feature].apply(get_list)

# %%
apps_df[['name', 'developers', 'categories', 'genres']].head(5)
# Out:
#                         name          developers  \
# 0             Counter-Strike             [Valve]
# 1      Team Fortress Classic             [Valve]
# 2              Day of Defeat             [Valve]
# 3         Deathmatch Classic             [Valve]
# 4  Half-Life: Opposing Force  [Gearbox Software]
#
#                                           categories    genres
# 0  [Multi-player, PvP, Online PvP, Shared/Split S...  [Action]
# 1  [Multi-player, PvP, Online PvP, Shared/Split S...  [Action]
# 2           [Multi-player, Valve Anti-Cheat enabled]  [Action]
# 3  [Multi-player, PvP, Online PvP, Shared/Split S...  [Action]
# 4  [Single-player, Multi-player, Valve Anti-Cheat...  [Action]

# %%
def clean_data(x):
  if isinstance(x, list):
    return [str.lower(i.replace(" ", "")) for i in x]
  else:
    # Check if Developers exists
    if isinstance(x, str):
      return str.lower(x.replace(" ", ""))
    else:
      return ''

# %%
features = ['developers', 'categories', 'genres']
for feature in features:
  apps_df[feature] = apps_df[feature].apply(clean_data)

# %%
def create_soup(x):
  return ' '.join(x['categories']) + ' ' + ' '.join(x['developers']) + ' '.join(x['genres'])

# %%
apps_df['soup'] = apps_df.apply(create_soup, axis = 1)

# %%
apps_df['soup'].head(5)
# Out:
# 0    multi-player pvp onlinepvp shared/splitscreenp...
# 1    multi-player pvp onlinepvp shared/splitscreenp...
# 2      multi-player valveanti-cheatenabled valveaction
# 3    multi-player pvp onlinepvp shared/splitscreenp...
# 4    single-player multi-player valveanti-cheatenab...
# Name: soup, dtype: object

# %% [markdown]
# # Mix both Plot Description and Metadata Soup Together

# %%
def fit_data(apps_df):
  # Plot Description Recommender
  tfidf = TfidfVectorizer(stop_words = 'english')
  apps_df['detailed_description'] = apps_df['detailed_description'].fillna('')
  tfidf_matrix = tfidf.fit_transform(apps_df['detailed_description'])
  # print(tfidf_matrix.shape)

  cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

  # Metadata Recommender
  count = CountVectorizer(stop_words = 'english')
  count_matrix = count.fit_transform(apps_df['soup'])
  # print(count_matrix.shape)

  cosine_sim2 = cosine_similarity(count_matrix, count_matrix)
  indices = pd.Series(apps_df.index, index = apps_df['name']).drop_duplicates()

  return cosine_sim, cosine_sim2, indices

# %%
cosine_sim, cosine_sim2, indices = fit_data(apps_df)

# %%
# For the name, use difflib.get_close_matches
def get_recommendations(name, cosine_sim=cosine_sim, cosine_sim2=cosine_sim2):
  # Get similar name out of what the user type so when there is a typo, it's still fine
  similar_name = difflib.get_close_matches(word = name, possibilities = apps_df['name'], n = 10, cutoff = 0.35)

  # Unusable, spouts out error, will fix in the future
  # game_list_plot = []
  # for i in similar_name:
  #   plot_idx = indices[i]

  #   # Plot Description Recommender
  #   sim_scores_plot = list(enumerate(cosine_sim[plot_idx]))
  #   sim_scores_plot = sorted(sim_scores_plot, key = lambda x: x[1], reverse = True)
  #   sim_scores_plot = sim_scores_plot[1:11]
  #   game_indices_plot = [i[0] for i in sim_scores_plot]

  #   game_list_plot.append(apps_df['name'].iloc[game_indices_plot])

  game_list_metadata = []
  for i in similar_name:
    meta_idx = indices[i]

    # Metadata Recommender
    sim_scores_meta = list(enumerate(cosine_sim2[meta_idx]))
    sim_scores_meta = sorted(sim_scores_meta, key = lambda x: x[1], reverse = True)
    sim_scores_meta = sim_scores_meta[1:11]
    game_indices_meta = [i[0] for i in sim_scores_meta]

    game_list_metadata.append(apps_df['name'].iloc[game_indices_meta])

  # print(game_list_plot)
  # print("**************")
  # print(game_list_metadata)
  # game_list = game_list_plot.append(game_list_metadata)

  df = pd.concat(game_list_metadata)
  df = df.reset_index()
  df = df.drop(['index'], axis = 1)
  df = df.drop_duplicates()

  return df

# %%
rec_df = get_recommendations('Half-Life')

# %%
rec_df
# Out:
#                                               name
# 0                                    Left 4 Dead 2
# 1                                       Multiwinia
# 2                          Two Worlds Epic Edition
# 3                                  Quake III Arena
# 4         Star Wars: Battlefront 2 (Classic, 2005)
# 5                                 Two Worlds II HD
# 6            Heretic: Shadow of the Serpent Riders
# 7   Warhammer® 40,000: Dawn of War® - Dark Crusade
# 8                     Return to Castle Wolfenstein
# 9      Warhammer® 40,000: Dawn of War® - Soulstorm
# 10                        Half-Life 2: Episode One
# 11                                          Portal
# 12                        Half-Life 2: Episode Two
# 13                                     Alien Swarm
# 14                                     Psychonauts
# 15                                       X Rebirth
# 16                                    Blade Kitten
# 17                       Oddworld: Munch's Oddysee
# 18                                 Team Fortress 2
# 19                                  Planet Busters
# 20                         Half-Life 2: Lost Coast
# 21                           Half-Life: Blue Shift
# 22                  Counter-Strike: Condition Zero
# 23                       Half-Life: Opposing Force
# 24                                       Half-Life
# 25                                     Left 4 Dead
# 28                                    Crash Time 2
# 29                                   Shadowgrounds
# 30              Brothers in Arms: Road to Hill 30™
# 31               Brothers in Arms: Hell's Highway™
# 33                               Half-Life: Source
# 37                          Jagged Alliance 2 Gold
# 38                                     Arx Fatalis
# 39                                     Alpha Prime
# 50                                   Day of Defeat
# 51                    Half-Life Deathmatch: Source
# 53                                        Ricochet
# 54                                  Counter-Strike
# 55                           Team Fortress Classic
# 56                              Deathmatch Classic
# 57                          Counter-Strike: Source
# 58                           Day of Defeat: Source
# 59                   Red Orchestra: Ostfront 41-45
# 61                                     Half-Life 2
# 65                                  X2: The Threat
# 66                                     X3: Reunion
# 68                             X3: Terran Conflict
# 81                   Dark Messiah of Might & Magic
# 83                 Lost Planet™: Extreme Condition
# 86                                Rag Doll Kung Fu
# 87                                Dangerous Waters
# 88                         Space Empires IV Deluxe
# 89             Iron Warriors: T - 72 Tank Command
# 91                         Half-Life 2: Deathmatch

# %%
def calc_baseline(apps_df):
  metacritic_mean = apps_df['metacritic.score'].mean()
  recc_quantile = apps_df['recommendations.total'].quantile(0.9)

  qualified_df = apps_df.copy().loc[apps_df['recommendations.total'] >= recc_quantile]

  return qualified_df, metacritic_mean, recc_quantile

# %%
qualified_df, m, C = calc_baseline(apps_df)
qualified_df
# Out:
#      type                                         name  steam_appid  \
# 0    game                               Counter-Strike         10.0
# 4    game                    Half-Life: Opposing Force         50.0
# 6    game                                    Half-Life         70.0
# 7    game               Counter-Strike: Condition Zero         80.0
# 9    game                                  Half-Life 2        220.0
# 10   game                       Counter-Strike: Source        240.0
# 16   game                     Half-Life 2: Episode One        380.0
# 17   game                                       Portal        400.0
# 18   game                     Half-Life 2: Episode Two        420.0
# 19   game                              Team Fortress 2        440.0
# 20   game                                  Left 4 Dead        500.0
# 21   game                                Left 4 Dead 2        550.0
# 22   game                                       Dota 2        570.0
# 23   game                                     Portal 2        620.0
# 25   game             Counter-Strike: Global Offensive        730.0
# 28   game                                Killing Floor       1250.0
# 49   game                                  DOOM (1993)       2280.0
# 116  game              Plants vs. Zombies GOTY Edition       3590.0
# 134  game                                  Garry's Mod       4000.0
# 142  game          S.T.A.L.K.E.R.: Shadow of Chernobyl       4500.0
# 148  game  Total War: MEDIEVAL II – Definitive Edition       4700.0
# 165  game     Star Wars: Battlefront 2 (Classic, 2005)       6060.0
# 206  game                                 Just Cause 2       8190.0
# 215  game                            BioShock Infinite       8870.0
# 218  game                  Sid Meier's Civilization® V       8930.0
# 243  game                   Call of Duty: World at War      10090.0
# 250  game      Call of Duty®: Modern Warfare® 2 (2009)      10180.0
# 257  game       Total War: EMPIRE – Definitive Edition      10500.0
# 287  game                   Bully: Scholarship Edition      12200.0
# 288  game    Grand Theft Auto IV: The Complete Edition      12210.0
# 335  game    Assassin's Creed™: Director's Cut Edition      15100.0
#
#     required_age is_free                               detailed_description  \
# 0            0.0   False  Play the world's number 1 online action game. ...
# 4            0.0   False  Return to the Black Mesa Research Facility as ...
# 6            0.0   False  Named Game of the Year by over 50 publications...
# 7            0.0   False  With its extensive Tour of Duty campaign, a ne...
# 9            0.0   False  1998. HALF-LIFE sends a shock through the game...
# 10           0.0   False  THE NEXT INSTALLMENT OF THE WORLD'S # 1 ONLINE...
# 16           0.0   False  Half-Life 2 has sold over 4 million copies wor...
# 17           0.0   False  <p>Portal&trade; is a new single player game f...
# 18           0.0   False  <p>Half-Life&reg; 2: Episode Two is the second...
# 19           0.0    True  <p><strong>"The most fun you can have online"<...
# 20           0.0   False  From Valve (the creators of Counter-Strike, Ha...
# 21            17   False  Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 22           0.0    True  <strong>The most-played game on Steam.</strong...
# 23           0.0   False  Portal 2 draws from the award-winning formula ...
# 25           0.0    True  Counter-Strike: Global Offensive (CS:GO) расши...
# 28           0.0   False  Killing Floor is a Co-op Survival Horror FPS s...
# 49           0.0   False  Developed by id Software, and originally relea...
# 116          0.0   False  <img src="https://cdn.akamai.steamstatic.com/s...
# 134          0.0   False  Garry's Mod is a physics sandbox. There aren't...
# 142          0.0   False  <h1>S.T.A.L.K.E.R. 2: Heart of Chornobyl</h1><...
# 148          0.0   False  <img src="https://cdn.akamai.steamstatic.com/s...
# 165          0.0   False  With brand new space combat, playable Jedi cha...
# 206           18   False  <h1>JUST CAUSE 4</h1><p><a href="https://store...
# 215           17   False  Indebted to the wrong people, with his life on...
# 218          0.0   False  The Flagship Turn-Based Strategy Game Returns<...
# 243           18   False  Call of Duty is back, redefining war like you'...
# 250          0.0   False  The most-anticipated game of the year and the ...
# 257          0.0   False  <img src="https://cdn.akamai.steamstatic.com/s...
# 287          0.0   False  Bully: Scholarship Edition takes place at the ...
# 288          0.0   False  <h1>Important Updates To Grand Theft Auto IV a...
# 335          0.0   False  Assassin's Creed™ is the next-gen game develop...
#
#                                         about_the_game  \
# 0    Play the world's number 1 online action game. ...
# 4    Return to the Black Mesa Research Facility as ...
# 6    Named Game of the Year by over 50 publications...
# 7    With its extensive Tour of Duty campaign, a ne...
# 9    1998. HALF-LIFE sends a shock through the game...
# 10   THE NEXT INSTALLMENT OF THE WORLD'S # 1 ONLINE...
# 16   Half-Life 2 has sold over 4 million copies wor...
# 17   <p>Portal&trade; is a new single player game f...
# 18   <p>Half-Life&reg; 2: Episode Two is the second...
# 19   <p><strong>"The most fun you can have online"<...
# 20   From Valve (the creators of Counter-Strike, Ha...
# 21   Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 22   <strong>The most-played game on Steam.</strong...
# 23   Portal 2 draws from the award-winning formula ...
# 25   Counter-Strike: Global Offensive (CS:GO) расши...
# 28   Killing Floor is a Co-op Survival Horror FPS s...
# 49   Developed by id Software, and originally relea...
# 116  <img src="https://cdn.akamai.steamstatic.com/s...
# 134  Garry's Mod is a physics sandbox. There aren't...
# 142  The Zone, a place full of unfathomable wonders...
# 148  <img src="https://cdn.akamai.steamstatic.com/s...
# 165  With brand new space combat, playable Jedi cha...
# 206  <a href="https://store.steampowered.com/app/68...
# 215  Indebted to the wrong people, with his life on...
# 218  The Flagship Turn-Based Strategy Game Returns<...
# 243  Call of Duty is back, redefining war like you'...
# 250  The most-anticipated game of the year and the ...
# 257  <img src="https://cdn.akamai.steamstatic.com/s...
# 287  Bully: Scholarship Edition takes place at the ...
# 288  Niko Bellic, Johnny Klebitz, and Luis Lopez al...
# 335  Assassin's Creed™ is the next-gen game develop...
#
#                                      short_description  \
# 0    Play the world's number 1 online action game. ...
# 4    Return to the Black Mesa Research Facility as ...
# 6    Named Game of the Year by over 50 publications...
# 7    With its extensive Tour of Duty campaign, a ne...
# 9    1998. HALF-LIFE sends a shock through the game...
# 10   Counter-Strike: Source blends Counter-Strike's...
# 16   Half-Life 2 has sold over 4 million copies wor...
# 17   Portal&trade; is a new single player game from...
# 18   Half-Life&reg; 2: Episode Two is the second in...
# 19   Nine distinct classes provide a broad range of...
# 20   From Valve (the creators of Counter-Strike, Ha...
# 21   Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 22   Every day, millions of players worldwide enter...
# 23   The &quot;Perpetual Testing Initiative&quot; h...
# 25   Counter-Strike: Global Offensive (CS:GO) расши...
# 28   6-player co-op survival horror at its finest! ...
# 49   You’re a marine—one of Earth’s best—recently a...
# 116  Zombies are invading your home, and the only d...
# 134  Garry's Mod is a physics sandbox. There aren't...
# 142  S.T.A.L.K.E.R.: Shadow of Chernobyl tells a st...
# 148  Spanning the most turbulent era in Western his...
# 165  Join the rise of Darth Vader’s elite 501st Leg...
# 206  Dive into an adrenaline-fuelled free-roaming a...
# 215  Indebted to the wrong people, with his life on...
# 218  Create, discover, and download new player-crea...
# 243  Call of Duty is back, redefining war like you'...
# 250  The most-anticipated game of the year and the ...
# 257  Command the seas, control the land, forge a ne...
# 287  Bully tells the story of mischievous 15-year-o...
# 288  Niko Bellic, Johnny Klebitz and Luis Lopez all...
# 335  Assassin's Creed™ is the next-gen game develop...
#
#                                    supported_languages  \
# 0    English<strong>*</strong>, French<strong>*</st...
# 4                      English, French, German, Korean
# 6    English<strong>*</strong>, French<strong>*</st...
# 7    English, French, German, Italian, Spanish - Sp...
# 9    English<strong>*</strong>, French<strong>*</st...
# 10   English, French, German, Italian, Japanese, Ko...
# 16   English<strong>*</strong>, French<strong>*</st...
# 17   English<strong>*</strong>, French<strong>*</st...
# 18   English<strong>*</strong>, French<strong>*</st...
# 19   English<strong>*</strong>, Danish, Dutch, Finn...
# 20   English<strong>*</strong>, French<strong>*</st...
# 21   Danish, Dutch, English<strong>*</strong>, Finn...
# 22   Bulgarian, Czech, Danish, Dutch, English<stron...
# 23   English<strong>*</strong>, French<strong>*</st...
# 25   чешский, датский, нидерландский, английский<st...
# 28   English<strong>*</strong>, French<strong>*</st...
# 49   English, French, Italian, German, Spanish - Spain
# 116                                            English
# 134  English<strong>*</strong>, French, Italian, Ge...
# 142  English<strong>*</strong>, French<strong>*</st...
# 148  English<strong>*</strong>, French<strong>*</st...
# 165  English<strong>*</strong><br><strong>*</strong...
# 206  English<strong>*</strong>, French<strong>*</st...
# 215  English<strong>*</strong>, French<strong>*</st...
# 218  English<strong>*</strong>, French<strong>*</st...
# 243  English, French, Italian, German, Spanish - Spain
# 250  English, French, German, Italian, Spanish - Spain
# 257  English, French, Italian, German, Spanish - Sp...
# 287  Italian, German, Spanish - Spain, English<stro...
# 288  English<strong>*</strong>, French, Italian, Ge...
# 335  English, French, Italian, German, Spanish - Spain
#
#                                           header_image  ...  \
# 0    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 4    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 6    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 7    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 9    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 10   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 16   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 17   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 18   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 19   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 20   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 21   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 22   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 23   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 25   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 28   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 49   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 116  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 134  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 142  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 148  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 165  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 206  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 215  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 218  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 243  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 250  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 257  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 287  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 288  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 335  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
#
#                            pc_requirements.recommended controller_support  \
# 0                                                  NaN                NaN
# 4                                                  NaN                NaN
# 6                                                  NaN                NaN
# 7                                                  NaN                NaN
# 9                                                  NaN                NaN
# 10                                                 NaN                NaN
# 16                                                 NaN                NaN
# 17                                                 NaN                NaN
# 18                                                 NaN                NaN
# 19   <strong>Recommended:</strong><br><ul class="bb...                NaN
# 20   <strong>Recommended:</strong>                 ...               full
# 21   <strong>Recommended:</strong><br><ul class="bb...               full
# 22                                                 NaN                NaN
# 23                                                 NaN               full
# 25                                                 NaN               full
# 28   <strong>Recommended:</strong><br>             ...                NaN
# 49                                                 NaN               full
# 116                                                NaN                NaN
# 134  <strong>Recommended:</strong><br><ul class="bb...                NaN
# 142  <ul class="bb_ul"><li><strong>Supported OS: </...                NaN
# 148                                                NaN                NaN
# 165                                                NaN                NaN
# 206  <strong>Recommended:</strong><br>\t\t\t\t\t<ul...               full
# 215  <strong>Recommended:</strong><br><ul class="bb...               full
# 218  <strong>Recommended:</strong><br>\t\t\t\t\t<ul...                NaN
# 243                                                NaN                NaN
# 250                                                NaN                NaN
# 257                                                NaN                NaN
# 287                                                NaN                NaN
# 288                                                NaN                NaN
# 335                                                NaN                NaN
#
#                                                reviews  \
# 0                                                  NaN
# 4                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22   “A modern multiplayer masterpiece.”<br>9.5/10 ...
# 23                                                 NaN
# 25                                                 NaN
# 28                                                 NaN
# 49                                                 NaN
# 116  <strong>&quot;Funny, endless, ridiculously goo...
# 134  “It brings back the silly glee of unbridled ex...
# 142                                                NaN
# 148                                                NaN
# 165                                                NaN
# 206                                                NaN
# 215                                                NaN
# 218                                                NaN
# 243                                                NaN
# 250                                                NaN
# 257  &quot;This is one of the most playable, import...
# 287                                                NaN
# 288                                                NaN
# 335                                                NaN
#
#                         linux_requirements.recommended  \
# 0                                                  NaN
# 4                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 25                                                 NaN
# 28   <strong>Recommended:</strong><br><ul class="bb...
# 49                                                 NaN
# 116                                                NaN
# 134  <strong>Recommended:</strong><br><ul class="bb...
# 142                                                NaN
# 148  OS: <br />\r\nUbuntu 15.10<br />\r\nSteam OS 2...
# 165                                                NaN
# 206                                                NaN
# 215  <strong>Recommended</strong><br><ul class="bb_...
# 218                                                NaN
# 243                                                NaN
# 250                                                NaN
# 257  <strong> Recommended:</strong><br><ul class="b...
# 287                                                NaN
# 288                                                NaN
# 335                                                NaN
#
#                                           legal_notice pc_requirements  \
# 0                                                  NaN             NaN
# 4                                                  NaN             NaN
# 6                                                  NaN             NaN
# 7                                                  NaN             NaN
# 9                                                  NaN             NaN
# 10                                                 NaN             NaN
# 16                                                 NaN             NaN
# 17                                                 NaN             NaN
# 18                                                 NaN             NaN
# 19                                                 NaN             NaN
# 20                                                 NaN             NaN
# 21                                                 NaN             NaN
# 22                                                 NaN             NaN
# 23                                                 NaN             NaN
# 25                                                 NaN             NaN
# 28   Killing Floor ©2009-2015 by Tripwire Interacti...             NaN
# 49   © 2022 Bethesda Softworks LLC, a ZeniMax Media...             NaN
# 116  ©2009 PopCap Games, Inc. All rights reserved. ...             NaN
# 134                                                NaN             NaN
# 142                                                NaN             NaN
# 148                                                NaN             NaN
# 165  LucasArts, the LucasArts logo, STAR WARS and r...             NaN
# 206  Just Cause 2 © 2010 Square Enix Ltd. Published...             NaN
# 215  ©2002 – 2017 Take-Two interactive Software, In...             NaN
# 218  © 2007-2017 Take-Two Interactive Software and ...             NaN
# 243  © 2008 Activision Publishing, Inc., Activision...             NaN
# 250  © 2017 Activision Publishing, Inc. Activision ...             NaN
# 257  © SEGA. The Creative Assembly, Total War, Empi...             NaN
# 287  Other Requirements; Software installations req...             NaN
# 288  Other Requirements: Initial activation require...             NaN
# 335  © 2008 Ubisoft Entertainment. All Rights Reser...             NaN
#
#     drm_notice                       mac_requirements.recommended  \
# 0          NaN                                                NaN
# 4          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 16         NaN                                                NaN
# 17         NaN                                                NaN
# 18         NaN                                                NaN
# 19         NaN                                                NaN
# 20         NaN                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN
# 25         NaN                                                NaN
# 28         NaN                                                NaN
# 49         NaN                                                NaN
# 116        NaN                                                NaN
# 134        NaN  <strong>Recommended:</strong><br><ul class="bb...
# 142        NaN                                                NaN
# 148        NaN                                                NaN
# 165        NaN                                                NaN
# 206        NaN                                                NaN
# 215        NaN  <strong>Recommended:</strong><br><ul class="bb...
# 218        NaN  <strong>Recommended:</strong><br>\t\t\t\t\t\t<...
# 243        NaN                                                NaN
# 250        NaN                                                NaN
# 257        NaN                                                NaN
# 287        NaN                                                NaN
# 288        NaN                                                NaN
# 335        NaN                                                NaN
#
#          ext_user_account_notice  \
# 0                            NaN
# 4                            NaN
# 6                            NaN
# 7                            NaN
# 9                            NaN
# 10                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 25                           NaN
# 28                           NaN
# 49                           NaN
# 116                          NaN
# 134                          NaN
# 142                          NaN
# 148                          NaN
# 165                          NaN
# 206                          NaN
# 215                          NaN
# 218                          NaN
# 243                          NaN
# 250                          NaN
# 257                          NaN
# 287                          NaN
# 288  Rockstar Games Social Club
# 335                          NaN
#
#                                                   soup
# 0    multi-player pvp onlinepvp shared/splitscreenp...
# 4    single-player multi-player valveanti-cheatenab...
# 6    single-player multi-player pvp onlinepvp steam...
# 7    single-player multi-player valveanti-cheatenab...
# 9    single-player steamachievements steamtradingca...
# 10   multi-player cross-platformmultiplayer steamac...
# 16   single-player steamachievements captionsavaila...
# 17   single-player steamachievements captionsavaila...
# 18   single-player steamachievements captionsavaila...
# 19   multi-player cross-platformmultiplayer steamac...
# 20   single-player multi-player co-op steamachievem...
# 21   single-player multi-player pvp onlinepvp co-op...
# 22   multi-player co-op steamtradingcards steamwork...
# 23   single-player multi-player co-op onlineco-op s...
# 25   длянесколькихигроков достиженияsteam контролле...
# 28   single-player multi-player co-op cross-platfor...
# 49   single-player multi-player pvp shared/splitscr...
# 116  single-player steamachievements remoteplayonph...
# 134  single-player multi-player pvp onlinepvp lanpv...
# 142  single-player multi-player pvp onlinepvp lanpv...
# 148  single-player multi-player steamtradingcards c...
# 165  single-player multi-player pvp onlinepvp parti...
# 206  single-player steamachievements fullcontroller...
# 215  single-player steamachievements fullcontroller...
# 218  single-player multi-player steamachievements s...
# 243    single-player multi-player co-op treyarchaction
# 250  single-player multi-player co-op steamachievem...
# 257  single-player multi-player pvp onlinepvp lanpv...
# 287  single-player partialcontrollersupport rocksta...
# 288  single-player multi-player partialcontrollersu...
# 335  single-player partialcontrollersupport ubisoft...
#
# [31 rows x 65 columns]

# %%
# Function that computes the weighted rating of each game
def weighted_rating(x, m=m, C=C):
  v = x['recommendations.total']
  R = x['metacritic.score']

  # Calculation based on the IMDB formula
  return (v / (v + m) * R) + (m / (m + v) * C)

# %%
qualified_df['recc_score'] = qualified_df.apply(weighted_rating, axis = 1)

# %%
qualified_df
# Out:
#      type                                         name  steam_appid  \
# 0    game                               Counter-Strike         10.0
# 4    game                    Half-Life: Opposing Force         50.0
# 6    game                                    Half-Life         70.0
# 7    game               Counter-Strike: Condition Zero         80.0
# 9    game                                  Half-Life 2        220.0
# 10   game                       Counter-Strike: Source        240.0
# 16   game                     Half-Life 2: Episode One        380.0
# 17   game                                       Portal        400.0
# 18   game                     Half-Life 2: Episode Two        420.0
# 19   game                              Team Fortress 2        440.0
# 20   game                                  Left 4 Dead        500.0
# 21   game                                Left 4 Dead 2        550.0
# 22   game                                       Dota 2        570.0
# 23   game                                     Portal 2        620.0
# 25   game             Counter-Strike: Global Offensive        730.0
# 28   game                                Killing Floor       1250.0
# 49   game                                  DOOM (1993)       2280.0
# 116  game              Plants vs. Zombies GOTY Edition       3590.0
# 134  game                                  Garry's Mod       4000.0
# 142  game          S.T.A.L.K.E.R.: Shadow of Chernobyl       4500.0
# 148  game  Total War: MEDIEVAL II – Definitive Edition       4700.0
# 165  game     Star Wars: Battlefront 2 (Classic, 2005)       6060.0
# 206  game                                 Just Cause 2       8190.0
# 215  game                            BioShock Infinite       8870.0
# 218  game                  Sid Meier's Civilization® V       8930.0
# 243  game                   Call of Duty: World at War      10090.0
# 250  game      Call of Duty®: Modern Warfare® 2 (2009)      10180.0
# 257  game       Total War: EMPIRE – Definitive Edition      10500.0
# 287  game                   Bully: Scholarship Edition      12200.0
# 288  game    Grand Theft Auto IV: The Complete Edition      12210.0
# 335  game    Assassin's Creed™: Director's Cut Edition      15100.0
#
#     required_age is_free                               detailed_description  \
# 0            0.0   False  Play the world's number 1 online action game. ...
# 4            0.0   False  Return to the Black Mesa Research Facility as ...
# 6            0.0   False  Named Game of the Year by over 50 publications...
# 7            0.0   False  With its extensive Tour of Duty campaign, a ne...
# 9            0.0   False  1998. HALF-LIFE sends a shock through the game...
# 10           0.0   False  THE NEXT INSTALLMENT OF THE WORLD'S # 1 ONLINE...
# 16           0.0   False  Half-Life 2 has sold over 4 million copies wor...
# 17           0.0   False  <p>Portal&trade; is a new single player game f...
# 18           0.0   False  <p>Half-Life&reg; 2: Episode Two is the second...
# 19           0.0    True  <p><strong>"The most fun you can have online"<...
# 20           0.0   False  From Valve (the creators of Counter-Strike, Ha...
# 21            17   False  Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 22           0.0    True  <strong>The most-played game on Steam.</strong...
# 23           0.0   False  Portal 2 draws from the award-winning formula ...
# 25           0.0    True  Counter-Strike: Global Offensive (CS:GO) расши...
# 28           0.0   False  Killing Floor is a Co-op Survival Horror FPS s...
# 49           0.0   False  Developed by id Software, and originally relea...
# 116          0.0   False  <img src="https://cdn.akamai.steamstatic.com/s...
# 134          0.0   False  Garry's Mod is a physics sandbox. There aren't...
# 142          0.0   False  <h1>S.T.A.L.K.E.R. 2: Heart of Chornobyl</h1><...
# 148          0.0   False  <img src="https://cdn.akamai.steamstatic.com/s...
# 165          0.0   False  With brand new space combat, playable Jedi cha...
# 206           18   False  <h1>JUST CAUSE 4</h1><p><a href="https://store...
# 215           17   False  Indebted to the wrong people, with his life on...
# 218          0.0   False  The Flagship Turn-Based Strategy Game Returns<...
# 243           18   False  Call of Duty is back, redefining war like you'...
# 250          0.0   False  The most-anticipated game of the year and the ...
# 257          0.0   False  <img src="https://cdn.akamai.steamstatic.com/s...
# 287          0.0   False  Bully: Scholarship Edition takes place at the ...
# 288          0.0   False  <h1>Important Updates To Grand Theft Auto IV a...
# 335          0.0   False  Assassin's Creed™ is the next-gen game develop...
#
#                                         about_the_game  \
# 0    Play the world's number 1 online action game. ...
# 4    Return to the Black Mesa Research Facility as ...
# 6    Named Game of the Year by over 50 publications...
# 7    With its extensive Tour of Duty campaign, a ne...
# 9    1998. HALF-LIFE sends a shock through the game...
# 10   THE NEXT INSTALLMENT OF THE WORLD'S # 1 ONLINE...
# 16   Half-Life 2 has sold over 4 million copies wor...
# 17   <p>Portal&trade; is a new single player game f...
# 18   <p>Half-Life&reg; 2: Episode Two is the second...
# 19   <p><strong>"The most fun you can have online"<...
# 20   From Valve (the creators of Counter-Strike, Ha...
# 21   Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 22   <strong>The most-played game on Steam.</strong...
# 23   Portal 2 draws from the award-winning formula ...
# 25   Counter-Strike: Global Offensive (CS:GO) расши...
# 28   Killing Floor is a Co-op Survival Horror FPS s...
# 49   Developed by id Software, and originally relea...
# 116  <img src="https://cdn.akamai.steamstatic.com/s...
# 134  Garry's Mod is a physics sandbox. There aren't...
# 142  The Zone, a place full of unfathomable wonders...
# 148  <img src="https://cdn.akamai.steamstatic.com/s...
# 165  With brand new space combat, playable Jedi cha...
# 206  <a href="https://store.steampowered.com/app/68...
# 215  Indebted to the wrong people, with his life on...
# 218  The Flagship Turn-Based Strategy Game Returns<...
# 243  Call of Duty is back, redefining war like you'...
# 250  The most-anticipated game of the year and the ...
# 257  <img src="https://cdn.akamai.steamstatic.com/s...
# 287  Bully: Scholarship Edition takes place at the ...
# 288  Niko Bellic, Johnny Klebitz, and Luis Lopez al...
# 335  Assassin's Creed™ is the next-gen game develop...
#
#                                      short_description  \
# 0    Play the world's number 1 online action game. ...
# 4    Return to the Black Mesa Research Facility as ...
# 6    Named Game of the Year by over 50 publications...
# 7    With its extensive Tour of Duty campaign, a ne...
# 9    1998. HALF-LIFE sends a shock through the game...
# 10   Counter-Strike: Source blends Counter-Strike's...
# 16   Half-Life 2 has sold over 4 million copies wor...
# 17   Portal&trade; is a new single player game from...
# 18   Half-Life&reg; 2: Episode Two is the second in...
# 19   Nine distinct classes provide a broad range of...
# 20   From Valve (the creators of Counter-Strike, Ha...
# 21   Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 22   Every day, millions of players worldwide enter...
# 23   The &quot;Perpetual Testing Initiative&quot; h...
# 25   Counter-Strike: Global Offensive (CS:GO) расши...
# 28   6-player co-op survival horror at its finest! ...
# 49   You’re a marine—one of Earth’s best—recently a...
# 116  Zombies are invading your home, and the only d...
# 134  Garry's Mod is a physics sandbox. There aren't...
# 142  S.T.A.L.K.E.R.: Shadow of Chernobyl tells a st...
# 148  Spanning the most turbulent era in Western his...
# 165  Join the rise of Darth Vader’s elite 501st Leg...
# 206  Dive into an adrenaline-fuelled free-roaming a...
# 215  Indebted to the wrong people, with his life on...
# 218  Create, discover, and download new player-crea...
# 243  Call of Duty is back, redefining war like you'...
# 250  The most-anticipated game of the year and the ...
# 257  Command the seas, control the land, forge a ne...
# 287  Bully tells the story of mischievous 15-year-o...
# 288  Niko Bellic, Johnny Klebitz and Luis Lopez all...
# 335  Assassin's Creed™ is the next-gen game develop...
#
#                                    supported_languages  \
# 0    English<strong>*</strong>, French<strong>*</st...
# 4                      English, French, German, Korean
# 6    English<strong>*</strong>, French<strong>*</st...
# 7    English, French, German, Italian, Spanish - Sp...
# 9    English<strong>*</strong>, French<strong>*</st...
# 10   English, French, German, Italian, Japanese, Ko...
# 16   English<strong>*</strong>, French<strong>*</st...
# 17   English<strong>*</strong>, French<strong>*</st...
# 18   English<strong>*</strong>, French<strong>*</st...
# 19   English<strong>*</strong>, Danish, Dutch, Finn...
# 20   English<strong>*</strong>, French<strong>*</st...
# 21   Danish, Dutch, English<strong>*</strong>, Finn...
# 22   Bulgarian, Czech, Danish, Dutch, English<stron...
# 23   English<strong>*</strong>, French<strong>*</st...
# 25   чешский, датский, нидерландский, английский<st...
# 28   English<strong>*</strong>, French<strong>*</st...
# 49   English, French, Italian, German, Spanish - Spain
# 116                                            English
# 134  English<strong>*</strong>, French, Italian, Ge...
# 142  English<strong>*</strong>, French<strong>*</st...
# 148  English<strong>*</strong>, French<strong>*</st...
# 165  English<strong>*</strong><br><strong>*</strong...
# 206  English<strong>*</strong>, French<strong>*</st...
# 215  English<strong>*</strong>, French<strong>*</st...
# 218  English<strong>*</strong>, French<strong>*</st...
# 243  English, French, Italian, German, Spanish - Spain
# 250  English, French, German, Italian, Spanish - Spain
# 257  English, French, Italian, German, Spanish - Sp...
# 287  Italian, German, Spanish - Spain, English<stro...
# 288  English<strong>*</strong>, French, Italian, Ge...
# 335  English, French, Italian, German, Spanish - Spain
#
#                                           header_image  ...  \
# 0    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 4    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 6    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 7    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 9    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 10   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 16   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 17   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 18   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 19   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 20   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 21   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 22   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 23   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 25   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 28   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 49   https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 116  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 134  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 142  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 148  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 165  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 206  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 215  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 218  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 243  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 250  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 257  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 287  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 288  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 335  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
#
#     controller_support                                            reviews  \
# 0                  NaN                                                NaN
# 4                  NaN                                                NaN
# 6                  NaN                                                NaN
# 7                  NaN                                                NaN
# 9                  NaN                                                NaN
# 10                 NaN                                                NaN
# 16                 NaN                                                NaN
# 17                 NaN                                                NaN
# 18                 NaN                                                NaN
# 19                 NaN                                                NaN
# 20                full                                                NaN
# 21                full                                                NaN
# 22                 NaN  “A modern multiplayer masterpiece.”<br>9.5/10 ...
# 23                full                                                NaN
# 25                full                                                NaN
# 28                 NaN                                                NaN
# 49                full                                                NaN
# 116                NaN  <strong>&quot;Funny, endless, ridiculously goo...
# 134                NaN  “It brings back the silly glee of unbridled ex...
# 142                NaN                                                NaN
# 148                NaN                                                NaN
# 165                NaN                                                NaN
# 206               full                                                NaN
# 215               full                                                NaN
# 218                NaN                                                NaN
# 243                NaN                                                NaN
# 250                NaN                                                NaN
# 257                NaN  &quot;This is one of the most playable, import...
# 287                NaN                                                NaN
# 288                NaN                                                NaN
# 335                NaN                                                NaN
#
#                         linux_requirements.recommended  \
# 0                                                  NaN
# 4                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 25                                                 NaN
# 28   <strong>Recommended:</strong><br><ul class="bb...
# 49                                                 NaN
# 116                                                NaN
# 134  <strong>Recommended:</strong><br><ul class="bb...
# 142                                                NaN
# 148  OS: <br />\r\nUbuntu 15.10<br />\r\nSteam OS 2...
# 165                                                NaN
# 206                                                NaN
# 215  <strong>Recommended</strong><br><ul class="bb_...
# 218                                                NaN
# 243                                                NaN
# 250                                                NaN
# 257  <strong> Recommended:</strong><br><ul class="b...
# 287                                                NaN
# 288                                                NaN
# 335                                                NaN
#
#                                           legal_notice pc_requirements  \
# 0                                                  NaN             NaN
# 4                                                  NaN             NaN
# 6                                                  NaN             NaN
# 7                                                  NaN             NaN
# 9                                                  NaN             NaN
# 10                                                 NaN             NaN
# 16                                                 NaN             NaN
# 17                                                 NaN             NaN
# 18                                                 NaN             NaN
# 19                                                 NaN             NaN
# 20                                                 NaN             NaN
# 21                                                 NaN             NaN
# 22                                                 NaN             NaN
# 23                                                 NaN             NaN
# 25                                                 NaN             NaN
# 28   Killing Floor ©2009-2015 by Tripwire Interacti...             NaN
# 49   © 2022 Bethesda Softworks LLC, a ZeniMax Media...             NaN
# 116  ©2009 PopCap Games, Inc. All rights reserved. ...             NaN
# 134                                                NaN             NaN
# 142                                                NaN             NaN
# 148                                                NaN             NaN
# 165  LucasArts, the LucasArts logo, STAR WARS and r...             NaN
# 206  Just Cause 2 © 2010 Square Enix Ltd. Published...             NaN
# 215  ©2002 – 2017 Take-Two interactive Software, In...             NaN
# 218  © 2007-2017 Take-Two Interactive Software and ...             NaN
# 243  © 2008 Activision Publishing, Inc., Activision...             NaN
# 250  © 2017 Activision Publishing, Inc. Activision ...             NaN
# 257  © SEGA. The Creative Assembly, Total War, Empi...             NaN
# 287  Other Requirements; Software installations req...             NaN
# 288  Other Requirements: Initial activation require...             NaN
# 335  © 2008 Ubisoft Entertainment. All Rights Reser...             NaN
#
#     drm_notice                       mac_requirements.recommended  \
# 0          NaN                                                NaN
# 4          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 16         NaN                                                NaN
# 17         NaN                                                NaN
# 18         NaN                                                NaN
# 19         NaN                                                NaN
# 20         NaN                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN
# 25         NaN                                                NaN
# 28         NaN                                                NaN
# 49         NaN                                                NaN
# 116        NaN                                                NaN
# 134        NaN  <strong>Recommended:</strong><br><ul class="bb...
# 142        NaN                                                NaN
# 148        NaN                                                NaN
# 165        NaN                                                NaN
# 206        NaN                                                NaN
# 215        NaN  <strong>Recommended:</strong><br><ul class="bb...
# 218        NaN  <strong>Recommended:</strong><br>\t\t\t\t\t\t<...
# 243        NaN                                                NaN
# 250        NaN                                                NaN
# 257        NaN                                                NaN
# 287        NaN                                                NaN
# 288        NaN                                                NaN
# 335        NaN                                                NaN
#
#          ext_user_account_notice  \
# 0                            NaN
# 4                            NaN
# 6                            NaN
# 7                            NaN
# 9                            NaN
# 10                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 25                           NaN
# 28                           NaN
# 49                           NaN
# 116                          NaN
# 134                          NaN
# 142                          NaN
# 148                          NaN
# 165                          NaN
# 206                          NaN
# 215                          NaN
# 218                          NaN
# 243                          NaN
# 250                          NaN
# 257                          NaN
# 287                          NaN
# 288  Rockstar Games Social Club
# 335                          NaN
#
#                                                   soup  recc_score
# 0    multi-player pvp onlinepvp shared/splitscreenp...   95.430529
# 4    single-player multi-player valveanti-cheatenab...         NaN
# 6    single-player multi-player pvp onlinepvp steam...  109.421718
# 7    single-player multi-player valveanti-cheatenab...  125.161259
# 9    single-player steamachievements steamtradingca...  103.683950
# 10   multi-player cross-platformmultiplayer steamac...   97.649007
# 16   single-player steamachievements captionsavaila...  135.178111
# 17   single-player steamachievements captionsavaila...   98.653733
# 18   single-player steamachievements captionsavaila...  125.891395
# 19   multi-player cross-platformmultiplayer steamac...  140.155823
# 20   single-player multi-player co-op steamachievem...  113.556836
# 21   single-player multi-player pvp onlinepvp co-op...   90.782596
# 22   multi-player co-op steamtradingcards steamwork...  161.823974
# 23   single-player multi-player co-op onlineco-op s...   98.494995
# 25   длянесколькихигроков достиженияsteam контролле...   83.262940
# 28   single-player multi-player co-op cross-platfor...  100.179483
# 49   single-player multi-player pvp shared/splitscr...         NaN
# 116  single-player steamachievements remoteplayonph...   97.134467
# 134  single-player multi-player pvp onlinepvp lanpv...         NaN
# 142  single-player multi-player pvp onlinepvp lanpv...  118.061502
# 148  single-player multi-player steamtradingcards c...         NaN
# 165  single-player multi-player pvp onlinepvp parti...  102.068362
# 206  single-player steamachievements fullcontroller...  110.291402
# 215  single-player steamachievements fullcontroller...  104.384511
# 218  single-player multi-player steamachievements s...   98.773358
# 243    single-player multi-player co-op treyarchaction  109.491193
# 250  single-player multi-player co-op steamachievem...  121.099516
# 257  single-player multi-player pvp onlinepvp lanpv...  150.552916
# 287  single-player partialcontrollersupport rocksta...  113.863536
# 288  single-player multi-player partialcontrollersu...   98.975917
# 335  single-player partialcontrollersupport ubisoft...  144.295470
#
# [31 rows x 66 columns]

# %% [markdown]
# # Testing Individual Request

# %%
# This is more of a complete list however, it might show apps that are not 'GAMES'
# https://steamcommunity.com/discussions/forum/1/3017941618731696640/
# When using the storefront api, it is best to be getting your list appids from this interface IStoreService and then the method GetAppList instead.
# https://steamapi.xpaw.me/#IStoreService/GetAppList

# test_url = 'https://api.steampowered.com/ISteamApps/GetAppList/v2/'
# test_df = requests.get(url = test_url).json()
# test_df = pd.DataFrame(test_df)
# test_df = json_normalize(test_df['applist']['apps'])
# test_df = test_df.sort_values(by=['appid'], ascending = True)
# test_df = test_df.reset_index()
# test_df

# %%
app_detail_url = 'http://store.steampowered.com/api/appdetails?appids=570'
app_detail = requests.get(url = app_detail_url).json()

app_df = pd.DataFrame(app_detail)
app_df = json_normalize(app_df['570'])
app_df = app_df.drop(1)
app_df
# Out:
#    type    name  steam_appid  required_age is_free                dlc  \
# 0  game  Dota 2        570.0           0.0    True  [1241930, 652720]
#
#                                 detailed_description  \
# 0  <strong>The most-played game on Steam.</strong...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
#
#                                    short_description  \
# 0  Every day, millions of players worldwide enter...
#
#                                  supported_languages  ... platforms.linux  \
# 0  Bulgarian, Czech, Danish, Dutch, English<stron...  ...            True
#
#   metacritic.score                                     metacritic.url  \
# 0             90.0  https://www.metacritic.com/game/pc/dota-2?ftag...
#
#   recommendations.total release_date.coming_soon release_date.date  \
# 0               14327.0                    False       9 Jul, 2013
#
#   support_info.url support_info.email content_descriptors.ids  \
# 0                                                          []
#
#   content_descriptors.notes
# 0                       NaN
#
# [1 rows x 40 columns]

# %%
app_df.columns
# Out:
# Index(['type', 'name', 'steam_appid', 'required_age', 'is_free', 'dlc',
#        'detailed_description', 'about_the_game', 'short_description',
#        'supported_languages', 'reviews', 'header_image', 'capsule_image',
#        'capsule_imagev5', 'website', 'developers', 'publishers', 'packages',
#        'package_groups', 'categories', 'genres', 'screenshots', 'movies',
#        'background', 'background_raw', 'pc_requirements.minimum',
#        'mac_requirements.minimum', 'linux_requirements.minimum',
#        'platforms.windows', 'platforms.mac', 'platforms.linux',
#        'metacritic.score', 'metacritic.url', 'recommendations.total',
#        'release_date.coming_soon', 'release_date.date', 'support_info.url',
#        'support_info.email', 'content_descriptors.ids',
#        'content_descriptors.notes'],
#       dtype='object')

# %%
app_df['metacritic.score']
# Out:
# 0    90.0
# Name: metacritic.score, dtype: float64

# %%
app_df['recommendations.total']
# Out:
# 0    14327.0
# Name: recommendations.total, dtype: float64

# %%
app_review_url = 'https://store.steampowered.com/appreviews/10?json=1&language=all&purchase_type=all&num_per_page=0'
app_review = requests.get(url = app_review_url).json()['query_summary']
review_df = pd.json_normalize(app_review)

# %%
review_df
# Out:
#    num_reviews  review_score        review_score_desc  total_positive  \
# 0            0             9  Overwhelmingly Positive          218456
#
#    total_negative  total_reviews
# 0            5622         224078

# %%
review_df['review_score']
# Out:
# 0    9
# Name: review_score, dtype: int64

# %%
app_review
# Out:
# {'num_reviews': 0,
#  'review_score': 9,
#  'review_score_desc': 'Overwhelmingly Positive',
#  'total_positive': 218456,
#  'total_negative': 5622,
#  'total_reviews': 224078}
